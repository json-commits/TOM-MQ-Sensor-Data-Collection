# %%
import pandas as pd

clean_no_barrier_no_tray = pd.read_excel(f'12-11-2023/cleannobarriernotray_12-11-23.xlsx', index_col=0)
clean_no_barrier_no_tray = pd.concat(
    [clean_no_barrier_no_tray, 
     pd.read_excel(f'12-11-2023/cleannobarriernotray2_12-11-23.xlsx', index_col=0)])
clean_no_barrier_no_tray['data_label'] = 'clean_no_barrier_no_tray'
clean_no_barrier_no_tray
# Out:
#       time_A  A0   A1  A2   T_A  time_B   B0   B1  B2   T_B  ...  C0   C1  C2  \
# 0       0.05  39  375  88  24.8    0.03  106  312  90   NaN  ...  26  103  22
# 1       0.10  39  375  88  24.8    0.05  106  312  90   NaN  ...  26  103  22
# 2       0.17  39  374  88  24.8    0.13  106  312  90   NaN  ...  26  103  22
# 3       0.25  39  375  88  24.8    0.20  106  312  90   NaN  ...  26  103  22
# 4       0.32  39  375  87  24.8    0.28  106  312  90   NaN  ...  26  103  22
# ...      ...  ..  ...  ..   ...     ...  ...  ...  ..   ...  ...  ..  ...  ..
# 1894  150.82  36  333  81  24.1  154.83  102  281  84  24.1  ...  25   88  21
# 1895  150.90  36  333  82  24.1  154.91  102  281  84  24.1  ...  25   87  21
# 1896  150.98  36  332  82  24.1  154.99  102  281  84  24.1  ...  24   88  21
# 1897  151.06  36  332  82  24.1  155.08  102  281  84  24.1  ...  25   88  21
# 1898  151.14  36  332  81  24.1  155.16  102  281  84  24.1  ...  25   88  21
#
# ...

# %%
import pandas as pd

clean_with_barrier_and_tray = pd.read_excel(f'12-11-2023/cleanwithbarrierandtray_12-11-23.xlsx', index_col=0)
clean_with_barrier_and_tray = pd.concat(
    [clean_with_barrier_and_tray, 
     pd.read_excel(f'12-11-2023/cleanwithbarrierandtray2_12-11-23.xlsx', index_col=0)])
clean_with_barrier_and_tray['data_label'] = 'clean_with_barrier_and_tray'
clean_with_barrier_and_tray
# Out:
#       time_A  A0   A1  A2   T_A  time_B  B0   B1   B2   T_B  ...  C0  C1  C2  \
# 0       0.10  33  323  78  24.5    0.03  99  273   84  24.1  ...  20  84  20
# 1       0.17  33  323  78  24.5    0.06  98  273   84  24.1  ...  20  84  20
# 2       0.25  33  323  78  24.5    0.13  98  273   84  24.1  ...  20  83  21
# 3       0.32  33  323  78  24.5    0.21  99  273   84  24.1  ...  20  84  20
# 4       0.40  33  323  78  24.5    0.29  98  273   84  24.1  ...  20  84  20
# ...      ...  ..  ...  ..   ...     ...  ..  ...  ...   ...  ...  ..  ..  ..
# 1629  129.16  30  303  72  24.1  129.98  92  256  100  23.8  ...  17  78  19
# 1630  129.25  30  303  72  24.1  130.06  92  256  100  23.8  ...  17  78  19
# 1631  129.33  30  303  72  24.1  130.14  92  256  100  23.8  ...  17  78  20
# 1632  129.41  30  303  72  24.1  130.23  91  256  100  23.8  ...  17  78  19
# 1633  129.49  30  303  72  24.1  130.31  92  256  100  23.8  ...  17  78  19
#
# ...

# %%
import pandas as pd

master_df = pd.concat([clean_no_barrier_no_tray, clean_with_barrier_and_tray])
master_df
# Out:
#       time_A  A0   A1  A2   T_A  time_B   B0   B1   B2   T_B  ...  C0   C1  \
# 0       0.05  39  375  88  24.8    0.03  106  312   90   NaN  ...  26  103
# 1       0.10  39  375  88  24.8    0.05  106  312   90   NaN  ...  26  103
# 2       0.17  39  374  88  24.8    0.13  106  312   90   NaN  ...  26  103
# 3       0.25  39  375  88  24.8    0.20  106  312   90   NaN  ...  26  103
# 4       0.32  39  375  87  24.8    0.28  106  312   90   NaN  ...  26  103
# ...      ...  ..  ...  ..   ...     ...  ...  ...  ...   ...  ...  ..  ...
# 1629  129.16  30  303  72  24.1  129.98   92  256  100  23.8  ...  17   78
# 1630  129.25  30  303  72  24.1  130.06   92  256  100  23.8  ...  17   78
# 1631  129.33  30  303  72  24.1  130.14   92  256  100  23.8  ...  17   78
# 1632  129.41  30  303  72  24.1  130.23   91  256  100  23.8  ...  17   78
# 1633  129.49  30  303  72  24.1  130.31   92  256  100  23.8  ...  17   78
#
# ...

# %%
import pandas as pd
red_1 = pd.read_excel(f'Data (12-09-2023)/Red1.xlsx', index_col=0)
red_1.head()
# Out:
#    time_A  A0   A1  A2   T_A  time_B  B0   B1  B2  T_B  time_C  C0  C1  C2  \
# 0    7.90  22  216  60  23.0    7.95  85  145  81  NaN    0.03  40  63  18
# 1    7.98  21  215  60  23.0    7.87  85  145  81  NaN    0.06  40  63  18
# 2    7.94  22  215  61  23.0    7.95  85  145  81  NaN    0.13  41  64  18
# 3    0.03  22  216  60  23.0    0.03  85  145  81  NaN    0.20  40  64  19
# 4    0.06  21  216  61  23.0    0.05  85  145  81  NaN    0.28  39  64  19
#
#     T_C  time_D  D0   D1  D2  T_D
# 0  22.2    0.03  14  139  75  NaN
# 1  22.2    0.05  13  139  75  NaN
# 2  22.2    0.12  14  140  75  NaN
# 3  22.2    0.19  14  139  75  NaN
# 4  22.2    0.27  14  139  75  NaN

# %%
import pandas as pd
red_2 = pd.read_excel(f'Data (12-09-2023)/Red2.xlsx', index_col=0)
red_2.head()
# Out:
#    time_A  A0   A1  A2  T_A  time_B  B0   B1  B2  T_B  time_C  C0  C1  C2  \
# 0    0.03  21  198  56  NaN    0.03  80  136  60  NaN    0.03  25  59  17
# 1    0.05  21  198  57  NaN    0.05  80  136  60  NaN    0.06  26  59  17
# 2    0.12  21  199  56  NaN    0.12  81  135  60  NaN    0.13  26  59  17
# 3    0.19  21  199  57  NaN    0.19  81  136  60  NaN    0.20  25  59  17
# 4    0.27  21  198  57  NaN    0.27  81  136  60  NaN    0.28  25  60  17
#
#     T_C  time_D  D0   D1  D2  T_D
# 0  22.6    0.00  13  130  64  NaN
# 1  22.6    0.04  13  130  64  NaN
# 2  22.6    0.09  13  130  64  NaN
# 3  22.6    0.16  13  130  64  NaN
# 4  22.6    0.23  13  130  64  NaN

# %%
import pandas as pd
green_data = pd.DataFrame()
for i in range(1, 9):
    print(f"reading green{i}.xlsx...", end=" ")
    red_data = pd.concat([green_data, pd.read_excel(f'Data (12-09-2023)/Red{i}.xlsx', index_col=0)])
    print("done")
red_data['data_label'] = 'red'
red_data
# Out:
# reading Red1.xlsx... done
# reading Red2.xlsx... done
# reading Red3.xlsx... done
# reading Red4.xlsx... done
# reading Red5.xlsx... done
# reading Red6.xlsx... done
# reading Red7.xlsx... done
# reading Red8.xlsx... done
#       time_A  A0   A1  A2   T_A  time_B  B0   B1  B2  T_B  ...  C0  C1  C2  \
# 0       7.90  22  216  60  23.0    7.95  85  145  81  NaN  ...  40  63  18
# 1       7.98  21  215  60  23.0    7.87  85  145  81  NaN  ...  40  63  18
# 2       7.94  22  215  61  23.0    7.95  85  145  81  NaN  ...  41  64  18
# 3       0.03  22  216  60  23.0    0.03  85  145  81  NaN  ...  40  64  19
# 4       0.06  21  216  61  23.0    0.05  85  145  81  NaN  ...  39  64  19
# ...      ...  ..  ...  ..   ...     ...  ..  ...  ..  ...  ...  ..  ..  ..
# 1727  137.11  20  192  55  23.1  129.65  73  133  60  NaN  ...  36  62  17
# 1728  137.21  20  192  56  23.1  129.73  73  133  60  NaN  ...  35  62  16
# 1729  137.27  20  192  56  23.1  129.80  73  132  60  NaN  ...  36  62  17
# ...

# %%
breaker_data = pd.DataFrame()
for i in range(4, 14):
    if i == 10:
        continue
    print(f"reading Breaker{i}.xlsx...", end=" ")
    breaker_data = pd.concat([breaker_data, pd.read_excel(f'Data (12-09-2023)/Breaker{i}.xlsx', index_col=0)])
    print("done")
breaker_data['data_label'] = 'breaker'
breaker_data
# Out:
# reading Breaker4.xlsx... done
# reading Breaker5.xlsx... done
# reading Breaker6.xlsx... done
# reading Breaker7.xlsx... done
# reading Breaker8.xlsx... done
# reading Breaker9.xlsx... done
# reading Breaker11.xlsx... done
# reading Breaker12.xlsx... done
# reading Breaker13.xlsx... done
#       time_A  A0   A1  A2   T_A  time_B  B0   B1  B2  T_B  ...  C0  C1  C2  \
# 0       0.03  24  262  82  23.0    0.03  86  171  81  NaN  ...  13  62  20
# 1       0.06  24  262  83  23.0    0.05  86  171  81  NaN  ...  13  62  20
# 2       0.13  24  263  82  23.0    0.12  86  171  81  NaN  ...  13  62  20
# 3       0.21  24  263  82  23.0    0.19  86  171  81  NaN  ...  13  62  20
# 4       0.29  24  262  82  23.0    0.27  86  171  81  NaN  ...  13  62  20
# ...      ...  ..  ...  ..   ...     ...  ..  ...  ..  ...  ...  ..  ..  ..
# 1645  130.46  20  186  54  23.0  123.46  99  130  94  NaN  ...  38  62  16
# 1646  130.54  21  187  54  23.0  123.53  99  130  94  NaN  ...  37  62  15
# ...

# %%
turning_data = pd.DataFrame()
for i in range(3, 11):
    print(f"reading Turning{i}.xlsx...", end=" ")
    turning_data = pd.concat([turning_data, pd.read_excel(f'Data (12-09-2023)/Turning{i}.xlsx', index_col=0)])
    print("done")
turning_data['data_label'] = 'turning'
turning_data
# Out:
# reading Turning3.xlsx... done
# reading Turning4.xlsx... done
# reading Turning5.xlsx... done
# reading Turning6.xlsx... done
# reading Turning7.xlsx... done
# reading Turning8.xlsx... done
# reading Turning9.xlsx... done
# reading Turning10.xlsx... done
#       time_A  A0   A1  A2   T_A  time_B   B0   B1  B2  T_B  ...  C0  C1  C2  \
# 0       0.03  22  246  77  23.0    0.03   82  156  80  NaN  ...  14  62  20
# 1       0.06  23  246  77  23.0    0.05   82  156  81  NaN  ...  14  62  20
# 2       0.13  23  246  77  23.0    0.12   82  156  80  NaN  ...  14  62  20
# 3       0.21  22  246  77  23.0    0.19   82  156  80  NaN  ...  14  62  20
# 4       0.29  23  246  77  23.0    0.27   82  156  80  NaN  ...  14  62  20
# ...      ...  ..  ...  ..   ...     ...  ...  ...  ..  ...  ...  ..  ..  ..
# 1651  131.27  23  189  57  23.0  125.33  101  130  89  NaN  ...  38  62  16
# 1652  131.36  23  189  57  23.0  125.41  102  130  89  NaN  ...  38  62  17
# ...

# %%
import pandas as pd
clean_data = pd.DataFrame()

for i in ['Clean data 12-6-23.xlsx', 'clean2.xlsx']:
    print(f"reading {i}...", end=" ")
    clean_data = pd.concat([clean_data, pd.read_excel(f'Data (12-09-2023)/{i}', index_col=0)])
    print("done")
clean_data['data_label'] = 'clean'
clean_data
# Out:
# reading Clean data 12-6-23.xlsx... done
# reading clean2.xlsx... done
#       time_A  A0   A1  A2   T_A  time_B  B0   B1   B2  T_B  ...  C0  C1  C2  \
# 0      11.68  19  220  56  21.0    0.41  79  147   98  NaN  ...  46  61  18
# 1      10.00  18  221  56  21.0    0.49  79  147   98  NaN  ...  47  61  17
# 2       0.05  18  221  56  21.0    0.56  79  147   98  NaN  ...  47  62  18
# 3       0.10  18  220  56  21.0    0.63  79  147   98  NaN  ...  47  61  18
# 4       0.17  19  221  56  21.0    0.70  79  147   98  NaN  ...  48  61  17
# ...      ...  ..  ...  ..   ...     ...  ..  ...  ...  ...  ...  ..  ..  ..
# 2645  211.55  20  222  58  22.4  205.97  80  148  101  NaN  ...  48  63  19
# 2646  211.63  20  222  58  22.4  206.05  80  148  101  NaN  ...  49  63  18
# 2647  211.72  19  222  58  22.4  206.13  80  148  101  NaN  ...  48  63  18
# 2648  211.80  20  222  57  22.4  206.21  80  149  101  NaN  ...  48  63  18
# ...

# %%
import seaborn as sns
master_df = pd.concat([red_data, breaker_data, turning_data, clean_data])
master_df
# Out:
#       time_A  A0   A1  A2   T_A  time_B  B0   B1   B2  T_B  ...  C0  C1  C2  \
# 0       7.90  22  216  60  23.0    7.95  85  145   81  NaN  ...  40  63  18
# 1       7.98  21  215  60  23.0    7.87  85  145   81  NaN  ...  40  63  18
# 2       7.94  22  215  61  23.0    7.95  85  145   81  NaN  ...  41  64  18
# 3       0.03  22  216  60  23.0    0.03  85  145   81  NaN  ...  40  64  19
# 4       0.06  21  216  61  23.0    0.05  85  145   81  NaN  ...  39  64  19
# ...      ...  ..  ...  ..   ...     ...  ..  ...  ...  ...  ...  ..  ..  ..
# 2645  211.55  20  222  58  22.4  205.97  80  148  101  NaN  ...  48  63  19
# 2646  211.63  20  222  58  22.4  206.05  80  148  101  NaN  ...  49  63  18
# 2647  211.72  19  222  58  22.4  206.13  80  148  101  NaN  ...  48  63  18
# 2648  211.80  20  222  57  22.4  206.21  80  149  101  NaN  ...  48  63  18
# 2649  211.88  19  222  57  22.4  206.29  80  149  101  NaN  ...  48  62  18
#
#        T_C  time_D  D0   D1  D2  T_D  data_label
# ...

# %%
# master_df = pd.concat([red_data, breaker_data, turning_data])
import seaborn as sns

A0_plot = sns.lmplot(data=master_df, x='time_A', y='A1', hue='data_label', legend='full', markers='x')
# for df in red_dfs[1:]:
#     A0_plot = sns.scatterplot(data=df, x='time_A', y='A0', ax=A0_plot)
    
A0_plot
# Out:
# C:\Users\jsonf\Documents\JetBrains\PycharmProjects\arduinoSerialRead\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import pandas as pd
new_clean_data = pd.read_excel(f'clean1_12-09-23.xlsx', index_col=0)
new_clean_data['data_label'] = 'new_clean'
new_clean_data
# Out:
#       time_A  A0   A1  A2   T_A  time_B  B0   B1  B2  T_B  ...  C0  C1  C2  \
# 0       0.03  16  212  52  25.8    0.03  49  164  51  NaN  ...  12  58  16
# 1       0.06  17  212  51  25.8    0.05  49  164  52  NaN  ...  13  58  16
# 2       0.13  17  212  52  25.8    0.12  49  164  52  NaN  ...  12  58  16
# 3       0.21  16  212  52  25.8    0.19  49  164  51  NaN  ...  12  58  16
# 4       0.29  16  212  52  25.8    0.27  49  164  52  NaN  ...  12  58  16
# ...      ...  ..  ...  ..   ...     ...  ..  ...  ..  ...  ...  ..  ..  ..
# 1621  128.52  17  210  53  24.8  121.61  68  162  66  NaN  ...  13  57  16
# 1622  128.60  17  210  54  24.8  121.69  68  162  66  NaN  ...  13  57  16
# 1623  128.68  17  210  53  24.8  121.76  69  162  66  NaN  ...  13  57  16
# 1624  128.76  17  210  53  24.8  121.84  69  162  66  NaN  ...  13  57  16
# 1625  128.84  17  210  53  24.8  121.92  69  162  66  NaN  ...  13  57  16
#
#        T_C  time_D  D0   D1   D2  T_D  data_label
# ...

# %%
clean_1_df = pd.read_excel(f'clean2_12-09-23.xlsx', index_col=0)
clean_1_df['data_label'] = 'clean_2'

clean_2_df = pd.read_excel(f'aeration4_12-09-23.xlsx', index_col=0)
clean_2_df['data_label'] = 'aeartion_4'

master_df = pd.concat([clean_1_df, clean_2_df])
master_df
# Out:
#       time_A  A0   A1  A2   T_A  time_B  B0   B1  B2   T_B  ...  C0  C1  C2  \
# 0       0.03  26  200  66  23.8    0.03  77  144  75  23.8  ...  15  67  16
# 1       0.06  26  200  66  23.8    0.06  77  144  75  23.8  ...  14  67  17
# 2       0.13  26  200  66  23.8    0.13  77  144  75  23.8  ...  14  67  16
# 3       0.21  26  200  66  23.8    0.21  77  144  75  23.8  ...  14  67  16
# 4       0.29  25  200  66  23.8    0.29  77  144  75  23.8  ...  14  67  16
# ...      ...  ..  ...  ..   ...     ...  ..  ...  ..   ...  ...  ..  ..  ..
# 3885  312.11  27  183  64  22.6  312.11  78  133  68  22.6  ...  16  60  16
# 3886  312.19  28  183  63  22.6  312.19  78  133  68  22.6  ...  16  60  16
# 3887  312.27  28  183  64  22.6  312.27  78  133  68  22.6  ...  16  60  16
# 3888  312.35  28  183  63  22.6  312.35  78  133  68  22.6  ...  16  59  15
# 3889  312.43  28  183  63  22.6  312.43  77  133  68  22.6  ...  16  60  16
#
#        T_C  time_D  D0   D1  D2   T_D  data_label
# ...

# %%
import seaborn as sns
# master_df = pd.concat([red_data, breaker_data, turning_data, clean_data, new_clean_data])

A0_plot = sns.lmplot(data=master_df[master_df.time_A > 130.00], x='time_A', y='A0', hue='data_label', legend='full', markers='x')
A0_plot
# Out:
# C:\Users\jsonf\Documents\JetBrains\PycharmProjects\arduinoSerialRead\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
master_df[master_df.time_A > 120.00]
# Out:
#       time_A  A0   A1  A2   T_A  time_B  B0   B1  B2   T_B  ...  C0  C1  C2  \
# 1517  120.08  21  199  63  23.8  120.08  71  143  71  23.8  ...  13  66  16
# 1518  120.16  21  199  64  23.8  120.16  71  143  71  23.8  ...  13  66  16
# 1519  120.25  21  199  63  23.8  120.25  71  143  71  23.8  ...  13  66  16
# 1520  120.33  21  199  63  23.8  120.33  71  143  72  23.8  ...  13  66  16
# 1521  120.41  22  199  63  23.8  120.41  71  143  72  23.8  ...  13  66  16
# ...      ...  ..  ...  ..   ...     ...  ..  ...  ..   ...  ...  ..  ..  ..
# 3885  312.11  27  183  64  22.6  312.11  78  133  68  22.6  ...  16  60  16
# 3886  312.19  28  183  63  22.6  312.19  78  133  68  22.6  ...  16  60  16
# 3887  312.27  28  183  64  22.6  312.27  78  133  68  22.6  ...  16  60  16
# 3888  312.35  28  183  63  22.6  312.35  78  133  68  22.6  ...  16  59  15
# 3889  312.43  28  183  63  22.6  312.43  77  133  68  22.6  ...  16  60  16
#
#        T_C  time_D  D0   D1  D2   T_D  data_label
# ...

# %%
import pandas as pd

green_data = pd.DataFrame()

for i in range(1, 17):
    print(f"reading green{i}.xlsx...", end=" ")
    green_data = pd.concat([green_data, pd.read_excel(f'raw_data (12-09-2023) (1)/xlsx/green{i}_12-09-23.xlsx', index_col=0)])
    print("done")
green_data['data_label'] = 'green_last_week'
green_data
# Out:
# reading green1.xlsx... done
# reading green2.xlsx... done
# reading green3.xlsx... done
# reading green4.xlsx... done
# reading green5.xlsx... done
# reading green6.xlsx... done
# reading green7.xlsx... done
# reading green8.xlsx... done
# reading green9.xlsx... done
# reading green10.xlsx... done
# reading green11.xlsx... done
# reading green12.xlsx... done
# reading green13.xlsx... done
# reading green14.xlsx... done
# reading green15.xlsx... done
# reading green16.xlsx... done
#       time_A  A0   A1  A2   T_A  time_B  B0   B1  B2   T_B  ...  C0  C1  C2  \
# 0       0.03  22  192  62  23.4    0.03  68  139  70  23.0  ...  13  61  16
# 1       0.06  21  192  62  23.4    0.06  68  139  71  23.0  ...  13  62  16
# 2       0.13  21  192  62  23.4    0.13  68  139  71  23.0  ...  13  61  16
# 3       0.21  21  192  62  23.4    0.21  68  139  71  23.0  ...  13  61  16
# 4       0.29  21  192  62  23.4    0.29  68  139  70  23.0  ...  13  62  16
# ...

# %%
green_data.describe()
# Out:
#              time_A            A0            A1            A2           T_A  \
# count  29776.000000  29776.000000  29776.000000  29776.000000  29776.000000
# mean      74.559737     23.662480    182.789562     62.911607     22.835582
# std       44.696674      1.911017      4.921283      1.879880      0.214969
# min        0.030000     20.000000    173.000000     59.000000     22.200000
# 25%       36.450000     23.000000    178.000000     62.000000     22.600000
# 50%       73.190000     23.000000    184.000000     62.000000     23.000000
# 75%      110.190000     25.000000    186.000000     64.000000     23.000000
# max      189.410000     32.000000    192.000000     71.000000     23.400000
#
#              time_B            B0            B1            B2           T_B  \
# count  29776.000000  29776.000000  29776.000000  29776.000000  29776.000000
# mean      74.559893     77.494996    132.363246     72.335371     22.794593
# ...

# %%
import pandas as pd

green_data_last_week = pd.DataFrame()

for i in range(1, 9):
    print(f"reading green{i}.xlsx...", end=" ")
    green_data_last_week = pd.concat([green_data_last_week, pd.read_excel(f'12-11-2023/green{i}_12-11-23.xlsx', index_col=0)])
    print("done")

green_data_last_week['data_label'] = 'green_today'

green_data_last_week
# Out:
# reading green1.xlsx... done
# reading green2.xlsx... done
# reading green3.xlsx... done
# reading green4.xlsx... done
# reading green5.xlsx... done
# reading green6.xlsx... done
# reading green7.xlsx... done
# reading green8.xlsx... done
#       time_A  A0   A1  A2   T_A  time_B  B0   B1  B2   T_B  ...  C0  C1  C2  \
# 0       0.03  31  272  67  23.4    0.03  88  225  93  23.4  ...  17  72  20
# 1       0.06  30  272  67  23.4    0.06  87  225  93  23.4  ...  17  72  20
# 2       0.13  30  272  68  23.4    0.13  88  225  93  23.4  ...  16  72  20
# 3       0.21  30  272  67  23.4    0.21  88  225  93  23.4  ...  16  72  19
# 4       0.29  30  272  68  23.4    0.29  88  225  93  23.4  ...  17  72  19
# ...      ...  ..  ...  ..   ...     ...  ..  ...  ..   ...  ...  ..  ..  ..
# 1553  123.02  29  223  67  24.1  123.02  89  175  90  23.8  ...  15  69  18
# 1554  123.08  29  223  67  24.1  123.08  89  175  90  23.8  ...  15  69  18
# ...

# %%
green_data_last_week.describe()
# Out:
#              time_A            A0            A1            A2           T_A  \
# count  12859.000000  12859.000000  12859.000000  12859.000000  12859.000000
# mean      63.310894     29.254141    232.124893     64.427483     22.673311
# std       36.793767      1.082729     17.889795      2.001888      0.541302
# min        0.030000     26.000000    210.000000     61.000000     22.200000
# 25%       31.470000     29.000000    222.000000     63.000000     22.200000
# 50%       63.230000     29.000000    229.000000     64.000000     22.600000
# 75%       94.940000     30.000000    245.000000     66.000000     22.600000
# max      129.570000     32.000000    272.000000     69.000000     24.100000
#
#              time_B            B0            B1            B2           T_B  \
# count  12859.000000  12859.000000  12859.000000  12859.000000  12859.000000
# mean      63.315412     85.772222    186.645929     84.465899     22.599261
# ...

# %%
import pandas as pd

master_df = pd.concat([green_data_last_week, breaker_data])

# %%
import seaborn as sns

A0_plot = sns.lmplot(data=master_df, x='time_A', y='A0', hue='data_label', legend='full', markers='x')

A0_plot
# Out:
# C:\Users\jsonf\Documents\JetBrains\PycharmProjects\arduinoSerialRead\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import pandas as pd

breaker_data = pd.DataFrame()

for i in range(1, 8):
    print(f"reading Breaker{i}.xlsx...", end=" ")
    breaker_data = pd.concat([breaker_data, pd.read_excel(f'12-11-2023/breaker{i}_12-11-23.xlsx', index_col=0)])
    print("done")

breaker_data['data_label'] = 'breaker_today'

breaker_data
# Out:
# reading Breaker1.xlsx... done
# reading Breaker2.xlsx... done
# reading Breaker3.xlsx... done
# reading Breaker4.xlsx... done
# reading Breaker5.xlsx... done
# reading Breaker6.xlsx... done
# reading Breaker7.xlsx... done
#       time_A  A0   A1  A2   T_A  time_B  B0   B1  B2   T_B  ...  C0  C1  C2  \
# 0       0.10  19  190  54  23.0    0.05  72  144  61  23.0  ...  14  66  16
# 1       0.17  19  190  54  23.0    0.10  72  144  62  23.0  ...  14  66  16
# 2       0.25  19  190  54  23.0    0.17  72  144  62  23.0  ...  14  67  16
# 3       0.32  19  190  54  23.0    0.25  72  144  61  23.0  ...  14  66  16
# 4       0.40  19  190  54  23.0    0.32  72  144  61  23.0  ...  14  66  16
# ...      ...  ..  ...  ..   ...     ...  ..  ...  ..   ...  ...  ..  ..  ..
# 1553  123.02  22  182  62  23.0  123.02  80  134  88  23.0  ...  14  68  17
# 1554  123.08  22  182  61  23.0  123.08  80  134  88  23.0  ...  14  68  17
# ...

# %%
breaker_data.describe()
# Out:
#              time_A            A0            A1            A2           T_A  \
# count  10819.000000  10819.000000  10819.000000  10819.000000  10819.000000
# mean      61.443207     22.059432    185.099177     60.680285     23.001812
# std       35.633363      1.959348      2.853005      3.241598      0.281359
# min        0.030000     18.000000    181.000000     54.000000     22.600000
# 25%       30.250000     20.000000    183.000000     59.000000     23.000000
# 50%       61.650000     22.000000    184.000000     61.000000     23.000000
# 75%       92.150000     23.000000    188.000000     63.000000     23.000000
# max      123.330000     26.000000    191.000000     66.000000     23.800000
#
#              time_B            B0            B1            B2           T_B  \
# count  10819.000000  10819.000000  10819.000000  10819.000000  10819.000000
# mean      61.470421     80.753397    137.485165     77.949164     22.848248
# ...

# %%
import os
import pandas as pd

master_df = pd.DataFrame()
files_path = '01-16-2024/xlsx'
files_list = os.listdir(files_path)
for i in range(len(files_list)):
    print(f"{((i + 1) / len(files_list)): .0%} reading {files_list[i]}...", end=" ")
    data_label = files_list[i]
    
    df = pd.read_excel(f'{files_path}/{files_list[i]}', index_col=0)
    df['file_origin'] = data_label
    data_label_classification = ""
    if ('bruised' in data_label) or ('Bruised' in data_label):
        data_label_classification += 'bruised_'
    if ('aeration' in data_label) or ('Aeration' in data_label):
        data_label_classification += 'aeration'
    elif ('clean' in data_label) or ('Clean' in data_label):
        data_label_classification += 'clean'
    elif ('green' in data_label) or ('Green' in data_label):
        data_label_classification += 'green'
    elif ('breaker' in data_label) or ('Breaker' in data_label):
        data_label_classification += 'breaker'
    elif ('turning' in data_label) or ('Turning' in data_label):
        data_label_classification += 'turning'
    elif ('red' in data_label) or ('Red' in data_label):
            data_label_classification += 'red'
    elif ('orange' in data_label) or ('Orange' in data_label):
        data_label_classification += 'red_bruised'
    elif ('spoiled' in data_label) or ('Spoiled' in data_label):
        data_label_classification += 'spoiled'
    else:
        data_label_classification = data_label[:-14]
        
    df['data_label'] = data_label_classification
    master_df = pd.concat([master_df, df])
    print("done")
    
master_df
# Out:
#  6% reading breaker1_01-16-24.xlsx... done
#  11% reading breaker2_01-16-24.xlsx... done
#  17% reading breaker3_01-16-24.xlsx... done
#  22% reading breaker4_01-16-24.xlsx... done
#  28% reading clean1_01-16-24.xlsx... done
#  33% reading clean2_01-16-24.xlsx... done
#  39% reading greenABC1_01-16-24.xlsx... done
#  44% reading greenABC2_01-16-24.xlsx... done
#  50% reading greenABC3_01-16-24.xlsx... done
#  56% reading greenBCD1_01-16-24.xlsx... done
#  61% reading greenBCD2_01-16-24.xlsx... done
#  67% reading greenBCD3_01-16-24.xlsx... done
#  72% reading green_bruised_ABC1_01-16-24.xlsx... done
#  78% reading green_bruised_ABC2_01-16-24.xlsx... done
#  83% reading green_bruised_ABC3_01-16-24.xlsx... done
#  89% reading green_bruised_BCD1_01-16-24.xlsx... done
#  94% reading green_bruised_BCD2_01-16-24.xlsx... done
#  100% reading green_bruised_BCD3_01-16-24.xlsx... done
#       time_A    A0     A1     A2   T_A  time_B    B0    B1    B2   T_B  ...  \
# ...

# %%
m_df = pd.DataFrame()

for letter in ['A', 'B', 'C', 'D']:
    for number in [0, 1, 2, 'T']:
        if number == 'T':
            sensor_label = f'T_{letter}'
        else:
            sensor_label = f'{letter}{number}' 
            
        new_df = master_df[[f'time_{letter}', sensor_label, 'data_label', 'file_origin']]
        #new_df.loc['sensor_label'] = letter
        #new_df.loc['sensor_number'] = number
        new_df['sensor_label'] = letter
        new_df['sensor_number'] = number
        new_df['date_collected'] = master_df.file_origin.str[-13:-5]
        new_df.rename(columns={sensor_label: 'value', f'time_{letter}': 'time'}, inplace=True)
            
        m_df = pd.concat([m_df, new_df])

m_df
# Out:
# C:\Users\jsonf\AppData\Local\Temp\ipykernel_5980\2339851521.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['sensor_label'] = letter
# C:\Users\jsonf\AppData\Local\Temp\ipykernel_5980\2339851521.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['sensor_number'] = number
# C:\Users\jsonf\AppData\Local\Temp\ipykernel_5980\2339851521.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
m_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 485200 entries, 0 to 1601
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   time            485184 non-null  float64
#  1   value           454859 non-null  float64
#  2   data_label      485200 non-null  object
#  3   file_origin     485200 non-null  object
#  4   sensor_label    485200 non-null  object
#  5   sensor_number   485200 non-null  object
#  6   date_collected  485200 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 29.6+ MB

# %%
m_df
# Out:
#         time  value data_label                       file_origin sensor_label  \
# 0       0.03   39.0    breaker            breaker1_01-16-24.xlsx            A
# 1       0.06   39.0    breaker            breaker1_01-16-24.xlsx            A
# 2       0.14   39.0    breaker            breaker1_01-16-24.xlsx            A
# 3       0.22   39.0    breaker            breaker1_01-16-24.xlsx            A
# 4       0.30   39.0    breaker            breaker1_01-16-24.xlsx            A
# ...      ...    ...        ...                               ...          ...
# 1594  129.76   22.2      green  green_bruised_BCD3_01-16-24.xlsx            D
# 1595  129.86   22.2      green  green_bruised_BCD3_01-16-24.xlsx            D
# 1596  129.93   22.2      green  green_bruised_BCD3_01-16-24.xlsx            D
# 1597  130.01   22.2      green  green_bruised_BCD3_01-16-24.xlsx            D
# 1598  130.09   22.2      green  green_bruised_BCD3_01-16-24.xlsx            D
#
# ...

# %%
filtered_df = m_df[
    ~((((m_df.sensor_label == 'D') &
     (m_df.file_origin.str.contains('green_bruised_ABC1_01-16-24.xlsx') | 
      m_df.file_origin.str.contains('green_bruised_ABC2_01-16-24.xlsx') | 
      m_df.file_origin.str.contains('green_bruised_ABC3_01-16-24.xlsx') | 
      m_df.file_origin.str.contains('greenABC1_01-16-24.xlsx') | 
      m_df.file_origin.str.contains('greenABC2_01-16-24.xlsx') | 
      m_df.file_origin.str.contains('greenABC3_01-16-24.xlsx'))
     ) |
    ((m_df.sensor_label == 'A') &
     (m_df.file_origin.str.contains('green_bruised_BCD1_01-16-24.xlsx') | 
      m_df.file_origin.str.contains('green_bruised_BCD2_01-16-24.xlsx') | 
      m_df.file_origin.str.contains('green_bruised_BCD3_01-16-24.xlsx') | 
      m_df.file_origin.str.contains('greenBCD1_01-16-24.xlsx') | 
      m_df.file_origin.str.contains('greenBCD2_01-16-24.xlsx') | 
      m_df.file_origin.str.contains('greenBCD3_01-16-24.xlsx'))
     )))
]

filtered_df
# Out:
#         time  value     data_label                       file_origin  \
# 0       0.03   39.0        breaker            breaker1_01-16-24.xlsx
# 1       0.06   39.0        breaker            breaker1_01-16-24.xlsx
# 2       0.14   39.0        breaker            breaker1_01-16-24.xlsx
# 3       0.22   39.0        breaker            breaker1_01-16-24.xlsx
# 4       0.30   39.0        breaker            breaker1_01-16-24.xlsx
# ...      ...    ...            ...                               ...
# 1594  129.76   22.2  bruised_green  green_bruised_BCD3_01-16-24.xlsx
# 1595  129.86   22.2  bruised_green  green_bruised_BCD3_01-16-24.xlsx
# 1596  129.93   22.2  bruised_green  green_bruised_BCD3_01-16-24.xlsx
# 1597  130.01   22.2  bruised_green  green_bruised_BCD3_01-16-24.xlsx
# 1598  130.09   22.2  bruised_green  green_bruised_BCD3_01-16-24.xlsx
#
#      sensor_label sensor_number date_collected
# 0               A             0       01-16-24
# ...

# %%
filtered_df[filtered_df.file_origin.str.contains('green_bruised_ABC1_01-16-24.xlsx')]
# Out:
#         time  value     data_label                       file_origin  \
# 0       0.71   37.0  bruised_green  green_bruised_ABC1_01-16-24.xlsx
# 1       0.71   37.0  bruised_green  green_bruised_ABC1_01-16-24.xlsx
# 2       0.79   36.0  bruised_green  green_bruised_ABC1_01-16-24.xlsx
# 3       0.71   36.0  bruised_green  green_bruised_ABC1_01-16-24.xlsx
# 4       0.71   36.0  bruised_green  green_bruised_ABC1_01-16-24.xlsx
# ...      ...    ...            ...                               ...
# 1600  119.77   22.2  bruised_green  green_bruised_ABC1_01-16-24.xlsx
# 1601  119.84   22.2  bruised_green  green_bruised_ABC1_01-16-24.xlsx
# 1602  119.92   22.2  bruised_green  green_bruised_ABC1_01-16-24.xlsx
# 1603  120.00   22.2  bruised_green  green_bruised_ABC1_01-16-24.xlsx
# 1604  120.07   22.2  bruised_green  green_bruised_ABC1_01-16-24.xlsx
#
#      sensor_label sensor_number date_collected
# 0               A             0       01-16-24
# ...

# %%
# prints rows are floats
m_df[m_df.time.apply(lambda x: not isinstance(x, float))].file_origin.unique()

# def is_float(x):
#     try:
#         float(x)
#         return True
#     except:
#         print(x)
#         return False
# 
# m_df[m_df.time.apply(lambda x: is_float(x))]
# Out:
# array(['Breaker1_12-06-23.xlsx'], dtype=object)

# %%
m_df[m_df.time.str.contains('102.902.77')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 m_df[m_df.time.str.contains('102.902.77')]
#
# File ~\Documents\JetBrains\PycharmProjects\arduinoSerialRead\venv\Lib\site-packages\pandas\core\frame.py:3751, in DataFrame.__getitem__(self, key)
#    3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
# -> 3751 if com.is_bool_indexer(key):
#    3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\Documents\JetBrains\PycharmProjects\arduinoSerialRead\venv\Lib\site-packages\pandas\core\common.py:134, in is_bool_indexer(key)
#     130     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
# ...

# %%
for i in m_df.date_collected.unique():
    print(f'[{i}]: {list(m_df[m_df.date_collected == i].data_label.unique())}')
# Out:
# [12-11-23]: ['breaker', 'clean', 'green', 'red']
# [12-06-23]: ['breaker', 'red', 'turning']
# [12-05-23]: ['breaker', 'green', 'red', 'turning']
# [12-09-23]: ['breaker', 'clean', 'green']
# [12-12-23]: ['clean', 'red', 'spoiled', 'turning']
# [12-13-23]: ['clean', 'red_bruised']

# %%
filter_df = m_df[m_df.time < 120.00]
filter_df = filter_df[filter_df.data_label.str.contains('red|spoiled|turning|breaker|green')]
filter_df[filter_df.sensor_number == 'T'].describe()
# Out:
#                 time          value
# count  837747.000000  507938.000000
# mean       59.509269      22.786534
# std        34.641799       0.559481
# min         0.000000      20.600000
# 25%        29.470000      22.400000
# 50%        59.380000      22.600000
# 75%        89.450000      23.000000
# max       119.990000      24.100000

# %%
master_df.to_csv('master_df(12-05-23 to 12-13-23).csv')

# %%
m_df.to_csv('m_df(12-05-23 to 12-13-23).csv')

# %%
m_df[m_df.sensor_number == 1]
# Out:
#         time  value data_label              file_origin sensor_label  \
# 0        0.1  183.0    breaker  breaker10_12-11-23.xlsx            A
# 1       0.17  183.0    breaker  breaker10_12-11-23.xlsx            A
# 2       0.25  183.0    breaker  breaker10_12-11-23.xlsx            A
# 3       0.32  183.0    breaker  breaker10_12-11-23.xlsx            A
# 4        0.4  183.0    breaker  breaker10_12-11-23.xlsx            A
# ...      ...    ...        ...                      ...          ...
# 1597  119.76  195.0    turning   turning9_12-12-23.xlsx            D
# 1598  119.84  195.0    turning   turning9_12-12-23.xlsx            D
# 1599  119.92  195.0    turning   turning9_12-12-23.xlsx            D
# 1600   120.0  195.0    turning   turning9_12-12-23.xlsx            D
# 1601  120.07  195.0    turning   turning9_12-12-23.xlsx            D
#
#      sensor_number date_collected
# 0                1       12-11-23
# 1                1       12-11-23
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

filter_df = filtered_df[filtered_df.time < 120.00]
# filter_df = filter_df[filter_df.data_label.str.contains('red|spoiled|turning|breaker|green')]
# filter_df = filter_df[filter_df.data_label.str.contains('red|clean|red_bruised|breaker')]
# filter_df = filter_df[filter_df.sensor_number == 1]

colors = {'breaker': 'yellow', 'green': 'green', 'red': 'red', 'turning': 'orange', 'spoiled': 'brown', 'clean': 'blue', 'aeration': 'purple', 'red_bruised': 'pink', 'bruised_green': 'olive'}
sns.lmplot(data=filter_df, x='time', y='value', hue='data_label', col='sensor_number', palette=colors,
           row='sensor_label', legend='full', markers='x', facet_kws=dict(sharex=False, sharey=False))
# Out:
# C:\Users\jsonf\Documents\JetBrains\PycharmProjects\arduinoSerialRead\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

m_df = pd.read_csv('master_df(12-09-23 to 12-12-23).csv', index_col=0)

# %%
m_df[m_df.date_collected.str.contains('12-09-23|12-11-23')].data_label.unique()
# Out:
# array(['aeration', 'breaker', 'clean', 'green', 'red'], dtype=object)

# %%
filter_df = m_df[m_df.time < 120.00]
filter_df = filter_df[filter_df.data_label.str.contains('red|clean')]
filter_df = filter_df[filter_df.date_collected.str.contains('12-12-23')]

filter_df.data_label.unique()
# Out:
# array(['clean', 'red'], dtype=object)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

filter_df = m_df[m_df.time < 120.00]
filter_df = filter_df[filter_df.data_label.str.contains('red|clean')]
# filter_df = filter_df[filter_df.date_collected.str.contains('12-12-23')]
filter_df = filter_df[filter_df.sensor_number == 1]

filter_df = filter_df[filter_df.date_collected.str.contains('12-12-23|12-11-23')]


colors = {'breaker': 'yellow', 'green': 'green', 'red': 'red', 'turning': 'orange', 'spoiled': 'brown', 'clean': 'blue', 'aeration': 'purple'}
sns.lmplot(data=filter_df, x='time', y='value', hue='data_label', col='date_collected', palette=colors,
           row='sensor_label', legend='full', markers='x', facet_kws=dict(sharex=False, sharey=False))
# Out:
# C:\Users\jsonf\Documents\JetBrains\PycharmProjects\arduinoSerialRead\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

filter_df = m_df[m_df.time < 120.00]
filter_df = filter_df[filter_df.data_label.str.contains('green')]

colors = {'breaker': 'yellow', 'green': 'green', 'red': 'red', 'turning': 'orange', 'spoiled': 'brown'}
sns.lmplot(data=filter_df, x='time', y='value', hue='date_collected', col='sensor_number',
           row='sensor_label', legend='full', markers='x', facet_kws=dict(sharex=False, sharey=False))
# Out:
# C:\Users\jsonf\Documents\JetBrains\PycharmProjects\arduinoSerialRead\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import pandas as pd

files_to_read = [
    'raw_data (12-09-2023) (1)/xlsx/clean1_12-09-23.xlsx',
    'raw_data (12-09-2023) (1)/xlsx/clean2_12-09-23.xlsx',
    '12-11-2023/cleannobarriernotray2_12-11-23.xlsx',
    '12-11-2023/cleannobarriernotray_12-11-23.xlsx',
    '12-11-2023/cleanwithbarrierandtray2_12-11-23.xlsx',
    '12-11-2023/cleanwithbarrierandtray_12-11-23.xlsx',
    '12-12-2023/xlsx/cleannobarriernotray2_12-12-23.xlsx',
    '12-12-2023/xlsx/cleannobarriernotray_12-12-23.xlsx',
    '12-12-2023/xlsx/cleanwithbarrierandtray2_12-12-23.xlsx',
    '12-12-2023/xlsx/cleanwithbarrierandtray_12-12-23.xlsx',
]

master_df = pd.DataFrame()

for i in range(len(files_to_read)):
    df = pd.read_excel(files_to_read[i], index_col=0)
    
    if i in [0, 1]:
        df['date_collected'] = '12-09-2023'
    elif i in [2, 3, 4, 5]:
        df['date_collected'] = '12-11-2023'
    elif i in [6, 7, 8, 9]:
        df['date_collected'] = '12-12-2023'
        
    master_df = pd.concat([master_df, df])
    
master_df
# Out:
#       time_A  A0   A1  A2   T_A  time_B  B0   B1  B2  T_B  ...  C0  C1  C2  \
# 0       0.03  16  212  52  25.8    0.03  49  164  51  NaN  ...  12  58  16
# 1       0.06  17  212  51  25.8    0.05  49  164  52  NaN  ...  13  58  16
# 2       0.13  17  212  52  25.8    0.12  49  164  52  NaN  ...  12  58  16
# 3       0.21  16  212  52  25.8    0.19  49  164  51  NaN  ...  12  58  16
# 4       0.29  16  212  52  25.8    0.27  49  164  52  NaN  ...  12  58  16
# ...      ...  ..  ...  ..   ...     ...  ..  ...  ..  ...  ...  ..  ..  ..
# 1598  126.57  22  234  61  23.0  119.72  73  197  80  NaN  ...  12  59  15
# 1599  126.65  22  234  61  23.0  119.80  73  197  81  NaN  ...  12  59  15
# 1600  126.73  22  234  61  23.0  119.88  73  197  81  NaN  ...  11  59  15
# 1601  126.81  22  234  61  23.0  119.95  73  197  80  NaN  ...  12  59  15
# 1602  126.89  21  234  61  23.0  120.03  73  197  81  NaN  ...  11  59  15
#
#        T_C  time_D  D0   D1   D2   T_D  date_collected
# ...

# %%
m_df = pd.DataFrame()

for letter in ['A', 'B', 'C', 'D']:
    for number in [0, 1, 2, 'T']:
        if number == 'T':
            sensor_label = f'T_{letter}'
        else:
            sensor_label = f'{letter}{number}' 
            
            new_df = master_df[[f'time_{letter}', sensor_label, 'date_collected']]
            #new_df.loc['sensor_label'] = letter
            #new_df.loc['sensor_number'] = number
            new_df['sensor_label'] = letter
            new_df['sensor_number'] = number
            new_df.rename(columns={sensor_label: 'value', f'time_{letter}': 'time'}, inplace=True)
            
            m_df = pd.concat([m_df, new_df])

m_df
# Out:
# C:\Users\jsonf\AppData\Local\Temp\ipykernel_2220\499482467.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['sensor_label'] = letter
# C:\Users\jsonf\AppData\Local\Temp\ipykernel_2220\499482467.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['sensor_number'] = number
# C:\Users\jsonf\AppData\Local\Temp\ipykernel_2220\499482467.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

filter_df = m_df[m_df.time < 120.00]
# filter_df = filter_df[filter_df.data_label.str.contains('breaker|green|red')]

# colors = {'breaker': 'yellow', 'green': 'green', 'red': 'red', 'turning': 'orange'}
sns.lmplot(data=filter_df, x='time', y='value', hue='date_collected', col='sensor_number',
           row='sensor_label', legend='full', markers='x', facet_kws=dict(sharex=False, sharey=False))
# Out:
# C:\Users\jsonf\Documents\JetBrains\PycharmProjects\arduinoSerialRead\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
